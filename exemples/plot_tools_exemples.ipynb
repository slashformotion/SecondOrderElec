# %% [markdown]
# # Test SecondOrderElec.plot

# %% [markdown]
# Setup

# %%
import numpy as np
try:
    from SecondOrderElec.plot import plot_bode, plot_pzmap, plot_time
    from SecondOrderElec.core import BP
except ImportError:
    import sys
    sys.path.append('../.')
    from SecondOrderElec.plot import plot_bode, plot_pzmap, plot_time
    from SecondOrderElec.core import BP

# %% [markdown]
# ### Let's plot time related things !
# ---

# %%
# setup
x = np.linspace(-5,5,100)
fx = np.sin(x) + np.cos(x*50)*0.3 + np.cos(x*200)*0.2 # noisy sinusoidal curve

# %%
# let's plot
plot_time(x,fx)

# %% [markdown]
# ### Let's plot some frequency response !
# ---

# %%
w = np.logspace(0.1,5,10000)

# %%
filter_instance = BP(1,0.5,4000) # Bandpass filter with Tm=1, m=0.5, w0=4000 rad/s
t,s = filter_instance.freqresp(w)
plot_bode(t,s)

# %% [markdown]
# ### Let's plot somes poles and zeros
# ---

# %%
poles, zeros = np.array([complex(0.5,1), complex(2,1.5), complex(0.2,-12), complex(12.2,-4), complex(7,-2)]),np.array([complex(0.9,5)])

plot_pzmap(poles, zeros)
